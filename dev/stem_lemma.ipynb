# %% [markdown]
# # Understanding Japleen's Preprocessing

# %%
import numpy as np
import pandas as pd
import pickle
import gensim
import tqdm
import matplotlib.pyplot as plt
from joblib import Parallel, delayed
import csv
from csv import reader
from scipy import spatial
import functools
from nltk.stem.snowball import SnowballStemmer
import spacy
import click
from spacy.tokenizer import Tokenizer
import datetime
from spacy.lang.en import English

# %% [markdown]
# ## Parameters

# %%
# time to split
split_date = datetime.datetime.strptime('01-01-2010', '%d-%m-%Y')

# %% [markdown]
# ## Tokenizing ParlSpeech

# %%
x = pd.read_csv('/home/hubert/semantic-change-hansard/data/parlspeechv2/Corp_HouseOfCommons_V2.csv')

# %%
x.columns
# Out:
# Index(['date', 'agenda', 'speechnumber', 'speaker', 'party', 'party.facts.id',
#        'chair', 'terms', 'text', 'parliament', 'iso3country'],
#       dtype='object')

# %%
x.shape
# Out:
# (1956223, 11)

# %%
x.head()
# Out:
#          date                             agenda  speechnumber       speaker  \
# 0  1988-11-22                     Queen's Speech             1         CHAIR
# 1  1988-11-22  First Day [Debate On The Address]             2         CHAIR
# 2  1988-11-22  First Day [Debate On The Address]             3    Giles Shaw
# 3  1988-11-22  First Day [Debate On The Address]             4   John Maples
# 4  1988-11-22  First Day [Debate On The Address]             5  Neil Kinnock
#
#   party  party.facts.id  chair  terms  \
# 0   NaN             NaN   True     74
# 1   NaN             NaN   True     55
# 2   Con          1567.0  False   2511
# 3   Con          1567.0  False   1470
# 4   Lab          1516.0  False   2768
#
#                                                 text         parliament  \
# 0  I have to acquaint the House that this House h...  UK-HouseOfCommons
# 1  It may be for the convenience of the House if ...  UK-HouseOfCommons
# 2  I beg to move,. That an humble Address be pres...  UK-HouseOfCommons
# 3  I am delighted to second the motion. When I ha...  UK-HouseOfCommons
# 4  I am sure that I speak for the majority of hon...  UK-HouseOfCommons
#
#   iso3country
# 0         GBR
# 1         GBR
# 2         GBR
# 3         GBR
# 4         GBR

# %%
nlp = English()
tk = Tokenizer(nlp.vocab)

# %%
# x.text_tokenized = x.text.apply(tk, batch_size=50)
tokenized_texts = []

# %%
from concurrent.futures import ProcessPoolExecutor
import multiprocessing

n_cpus = multiprocessing.cpu_count()
print(f'Available CPUs: {n_cpus}')

batch_size=50

def divide_chunks(texts, n):
    # looping till length l
    for i in range(0, len(texts), n):
        yield texts[i:i + n]

def tokenize_batch(batch):
    batch_size=len(batch)
    return tk.pipe(batch, batch_size=batch_size)

# test one batch
list(tokenize_batch(x.text[:10]))[0]
# Out:
# Available CPUs: 20
# I have to acquaint the House that this House has this day attended Her Majesty in the House of Peers, and that Her Majesty was pleased to make a Most Gracious Speech from the Throne to both Houses of Parliament, of which I have, for greater accuracy, obtained a copy. I shall direct that the terms of the Gracious Speech be printed in the Votes and Proceedings. Copies are available in the Vote Office.

# %%
import nltk
from nltk.tokenize import RegexpTokenizer

def tki(sentence):
    sentence = sentence.lower()
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(sentence)
    return tokens

tokenised_text = x.text.apply(tki)

# %%
x['tokenized'] = tokenised_text

# %%
x
# Out:
#                date                                     agenda  speechnumber  \
# 0        1988-11-22                             Queen's Speech             1
# 1        1988-11-22          First Day [Debate On The Address]             2
# 2        1988-11-22          First Day [Debate On The Address]             3
# 3        1988-11-22          First Day [Debate On The Address]             4
# 4        1988-11-22          First Day [Debate On The Address]             5
# ...             ...                                        ...           ...
# 1956218  2019-12-17                        Election of Speaker            14
# 1956219  2019-12-17                        Election of Speaker            15
# 1956220  2019-12-17  MESSAGE TO ATTEND THE LORDS COMMISSIONERS            16
# 1956221  2019-12-17                              Members Sworn            17
# 1956222  2019-12-17                              Members Sworn            18
#
#               speaker party  party.facts.id  chair  terms  \
# 0               CHAIR   NaN             NaN   True     74
# 1               CHAIR   NaN             NaN   True     55
# 2          Giles Shaw   Con          1567.0  False   2511
# 3         John Maples   Con          1567.0  False   1470
# 4        Neil Kinnock   Lab          1516.0  False   2768
# ...               ...   ...             ...    ...    ...
# 1956218  Iain Stewart   Con          1567.0  False     34
# 1956219         CHAIR   NaN             NaN   True      7
# 1956220         CHAIR   NaN             NaN   True     82
# 1956221         CHAIR   NaN             NaN   True     54
# 1956222         CHAIR   NaN             NaN   True   1709
#
#                                                       text         parliament  \
# 0        I have to acquaint the House that this House h...  UK-HouseOfCommons
# 1        It may be for the convenience of the House if ...  UK-HouseOfCommons
# 2        I beg to move,. That an humble Address be pres...  UK-HouseOfCommons
# 3        I am delighted to second the motion. When I ha...  UK-HouseOfCommons
# 4        I am sure that I speak for the majority of hon...  UK-HouseOfCommons
# ...                                                    ...                ...
# 1956218  I have to signify to the House the pleasure of...  UK-HouseOfCommons
# 1956219              The House is suspended until 3.45 pm.  UK-HouseOfCommons
# 1956220  I have to report that this House has been in t...  UK-HouseOfCommons
# 1956221  I must now call on the Members of the House, a...  UK-HouseOfCommons
# 1956222  I should remind hon. Members that, until they ...  UK-HouseOfCommons
#
#         iso3country                                          tokenized
# 0               GBR  [i, have, to, acquaint, the, house, that, this...
# 1               GBR  [it, may, be, for, the, convenience, of, the, ...
# 2               GBR  [i, beg, to, move, that, an, humble, address, ...
# 3               GBR  [i, am, delighted, to, second, the, motion, wh...
# 4               GBR  [i, am, sure, that, i, speak, for, the, majori...
# ...             ...                                                ...
# 1956218         GBR  [i, have, to, signify, to, the, house, the, pl...
# 1956219         GBR      [the, house, is, suspended, until, 3, 45, pm]
# 1956220         GBR  [i, have, to, report, that, this, house, has, ...
# 1956221         GBR  [i, must, now, call, on, the, members, of, the...
# 1956222         GBR  [i, should, remind, hon, members, that, until,...
#
# [1956223 rows x 12 columns]

# %% [markdown]
# ## Experiments with previous Hansard data

# %%
import pickle
with open('/home/hubert/japleen/semantic-change-hansard-dev/Resources/hansard-speeches-post2010.pkl', 'rb') as f:
    hansard = pickle.load(f)

# %%
with open('/home/hubert/japleen/semantic-change-hansard-dev/Resources/TokenizedSpeeches_utf-8.csv', 'r') as read_obj:

    lemmasList = []
    # pass the file object to reader() to get the reader object
    csv_reader = reader(read_obj)
    # Iterate over each row in the csv using reader object
    for row in csv_reader: 
        lemmasList.append(row)
    print(len(lemmasList), 'Rows read')
# Out:
# 630368 Rows read

# %%
dictOfLemmas = {'Lemmas': lemmasList}
lemmasDf = pd.DataFrame(dictOfLemmas)
lemmasDf
# Out:
#                                                    Lemmas
# 0       [acquaint, house, house, day, attended, majest...
# 1       [call, mover, seconder, want, announce, propos...
# 2       [beg, move, humble, address, presented, majest...
# 3       [delighted, follow, right, member, hitchin, ha...
# 4       [sure, whole, house, join, paying, tribute, kn...
# ...                                                   ...
# 630363  [congratulate, gentleman, securing, debate, ma...
# 630364  [thank, gentleman, agree, underlying, lack, re...
# 630365  [congratulations, new, position, mr, speaker, ...
# 630366  [friend, right, open, clear, challenges, face,...
# 630367  [thank, friend, assiduous, campaigner, issue, ...
#
# [630368 rows x 1 columns]

# %%
#since index was missing values and didn't match with the lemmasDf index
df = hansard
df = df.reset_index(drop=True)
df = df.join(lemmasDf)
df['Lemmas']
# Out:
# 0         [acquaint, house, house, day, attended, majest...
# 1         [call, mover, seconder, want, announce, propos...
# 2         [beg, move, humble, address, presented, majest...
# 3         [delighted, follow, right, member, hitchin, ha...
# 4         [sure, whole, house, join, paying, tribute, kn...
#                                 ...
# 630363    [congratulate, gentleman, securing, debate, ma...
# 630364    [thank, gentleman, agree, underlying, lack, re...
# 630365    [congratulations, new, position, mr, speaker, ...
# 630366    [friend, right, open, clear, challenges, face,...
# 630367    [thank, friend, assiduous, campaigner, issue, ...
# Name: Lemmas, Length: 630368, dtype: object

# %%
df.iloc[0]['speech']
# Out:
# "I have to acquaint the House that this House has this day attended Her Majesty in the House of Peers, and that Her Majesty was pleased to make a Most Gracious Speech from the Throne to both Houses of Parliament, of which I have, for greater accuracy, obtained a copy.I shall direct that the terms of the Gracious Speech be printed in the Votes and Proceedings. Copies are available in the Vote Office.The Gracious Speech was as follows:My Lords and Members of the House of Commons My Government's legislative programme will be based upon the principles of freedom, fairness and responsibility. The first priority is to reduce the deficit and restore economic growth. Action will be taken to accelerate the reduction of the structural budget deficit. A new Office for Budget Responsibility will provide confidence in the management of the public finances. The tax and benefits system will be made fairer and simpler. Changes to National Insurance will safeguard jobs and support the economy. People will be supported into work with sanctions for those who refuse available jobs and the timetable for increasing the State Pension Age will be reviewed. Legislation will reform financial services regulation to learn from the financial crisis and to make fair and transparent payments to Equitable Life policy holders. My Government will support investment in new high-speed broadband internet connections, enable the construction of a high-speed railway network and reform the economic regulation of airports to benefit passengers. My Government will modernise the Royal Mail, in partnership with employees, and will ensure it benefits from private sector capital and disciplines. My Government will limit the number of non-European Union economic migrants entering the United Kingdom and end the detention of children for immigration purposes. Legislation will be introduced to improve energy efficiency in homes and businesses, to promote low carbon energy production and to secure energy supplies. My Government will remove barriers to flexible working and promote equal pay. My Government will seek to build a strong and fair society by reforming public services and encouraging individual and social responsibility. Legislation will be introduced to enable more schools to achieve academy status, give teachers greater freedom over the curriculum and allow new providers to run state schools. The voice of patients and the role of doctors will be strengthened in the National Health Service to improve public health alongside actions to reduce health inequalities. A commission will be appointed to consider a sustainable long-term structure for the operation of social care. A Bill will be introduced to make the police service more accountable to local people and to tackle alcohol-related violence and anti-social behaviour. The role of social enterprises, charities and co-operatives in our public services will be enhanced. The cost of bureaucracy and the number of public bodies will be reduced. A Bill will be introduced to devolve greater powers to councils and neighbourhoods and give local communities control over housing and planning decisions. Legislation will be introduced to stop uncompleted plans to create unitary councils. My Government will propose Parliamentary and political reform to restore trust in democratic institutions and rebalance the relationship between the citizen and the state. Measures will be brought forward to introduce fixed term Parliaments of five years. A Bill will be introduced for a referendum on the Alternative Vote system for the House of Commons and to create fewer and more equal sized constituencies. Constituents will be given the right to recall their Members of Parliament where they are guilty of serious wrongdoing. Proposals will be brought forward for a reformed second House that is wholly or mainly elected on the basis of proportional representation. Action will be taken to reform the funding of political parties. A draft Bill will  ...

# %%
df.iloc[0]['Lemmas']
# Out:
# ['acquaint',
#  'house',
#  'house',
#  'day',
#  'attended',
#  'majesty',
#  'house',
#  'peers',
#  'majesty',
#  'pleased',
#  'make',
#  'gracious',
#  'speech',
#  'throne',
#  'houses',
#  'parliament',
#  'greater',
#  'accuracy',
#  'obtained',
#  'shall',
#  'direct',
#  'terms',
#  'gracious',
#  'speech',
#  'printed',
#  'votes',
#  'proceedings',
#  'copies',
#  'available',
#  'vote',
#  'gracious',
#  'speech',
#  'follows',
#  'lords',
#  'members',
#  'house',
#  'commons',
#  'government',
#  'legislative',
#  'programme',
#  'based',
#  'upon',
#  'principles',
#  'freedom',
#  'fairness',
#  'responsibility',
#  'first',
#  'priority',
#  'reduce',
#  'deficit',
#  'restore',
#  'economic',
#  'growth',
#  'action',
#  'taken',
#  'accelerate',
#  'reduction',
#  'structural',
#  'budget',
#  'deficit',
#  'new',
#  'office',
#  'budget',
#  'responsibility',
#  'provide',
#  'confidence',
#  'management',
#  'public',
#  'finances',
#  'tax',
#  'benefits',
#  'system',
#  'made',
#  'fairer',
#  'simpler',
#  'changes',
#  'national',
#  'insurance',
#  'safeguard',
#  'jobs',
#  'support',
#  'economy',
#  'people',
#  'supported',
#  'work',
#  'sanctions',
#  'refuse',
#  'available',
#  'jobs',
#  'timetable',
#  'increasing',
#  'state',
#  'pension',
#  'age',
#  'reviewed',
#  'legislation',
#  'reform',
#  'financial',
#  'services',
#  'regulation',
#  'learn',
#  'financial',
#  'crisis',
#  'make',
#  'fair',
#  'transparent',
#  'payments',
#  'equitable',
#  'life',
#  'policy',
#  'holders',
#  'government',
#  'support',
#  'investment',
#  'new',
#  'broadband',
#  'internet',
#  'connections',
#  'enable',
#  'construction',
#  'railway',
#  'network',
#  'reform',
#  'economic',
#  'regulation',
#  'airports',
#  'benefit',
#  'passengers',
#  'government',
#  'modernise',
#  'royal',
#  'mail',
#  'partnership',
#  'employees',
#  'ensure',
#  'benefits',
#  'private',
#  'sector',
#  'capital',
#  'disciplines',
#  'government',
#  'limit',
#  'number',
#  'union',
#  'economic',
#  'migrants',
#  'entering',
#  'united',
#  'kingdom',
#  'end',
#  'detention',
#  'children',
#  'immigration',
#  'purposes',
#  'legislation',
#  'introduced',
#  'improve',
#  'energy',
#  'efficiency',
#  'homes',
#  'businesses',
#  'promote',
#  'low',
#  'carbon',
#  'energy',
#  'production',
#  'secure',
#  'energy',
#  'supplies',
#  'government',
#  'remove',
#  'barriers',
#  'flexible',
#  'working',
#  'promote',
#  'equal',
#  'pay',
#  'government',
#  'seek',
#  'build',
#  'strong',
#  'fair',
#  'society',
#  'reforming',
#  'public',
#  'services',
#  'encouraging',
#  'individual',
#  'social',
#  'responsibility',
#  'legislation',
#  'introduced',
#  'enable',
#  'schools',
#  'achieve',
#  'academy',
#  'status',
#  'give',
#  'teachers',
#  'greater',
#  'freedom',
#  'curriculum',
#  'allow',
#  'new',
#  'providers',
#  'run',
#  'state',
#  'schools',
#  'voice',
#  'patients',
#  'role',
#  'doctors',
#  'strengthened',
#  'national',
#  'health',
#  'service',
#  'improve',
#  'public',
#  'health',
#  'alongside',
#  'actions',
#  'reduce',
#  'health',
#  'inequalities',
#  'commission',
#  'appointed',
#  'consider',
#  'sustainable',
#  'structure',
#  'operation',
#  'social',
#  'care',
#  'bill',
#  'introduced',
#  'make',
#  'police',
#  'service',
#  'accountable',
#  'local',
#  'people',
#  'tackle',
#  'violence',
#  'behaviour',
#  'role',
#  'social',
#  'enterprises',
#  'charities',
#  'public',
#  'services',
#  'enhanced',
#  'cost',
#  'bureaucracy',
#  'number',
#  'public',
#  'bodies',
#  'reduced',
#  'bill',
#  'introduced',
#  'devolve',
#  'greater',
#  'powers',
#  'councils',
#  'neighbourhoods',
#  'give',
#  'local',
#  'communities',
#  'control',
#  'housing',
#  'planning',
#  'decisions',
#  'legislation',
#  'introduced',
#  'stop',
#  'uncompleted',
#  'plans',
#  'create',
#  'unitary',
#  'councils',
#  'government',
#  'propose',
#  'parliamentary',
#  'political',
#  'reform',
#  'restore',
#  'trust',
#  'democratic',
#  'institutions',
#  'rebalance',
#  'relationship',
#  'citizen',
#  'state',
#  'measures',
#  'brought',
#  'forward',
#  'introduce',
#  'fixed',
#  'term',
#  'parliaments',
#  'five',
#  'years',
#  'bill',
#  'introduced',
#  'referendum',
#  'alternative',
#  'vote',
#  'system',
#  'house',
#  'commons',
#  'create',
#  'fewer',
#  'equal',
#  'sized',
#  'constituencies',
#  'constituents',
#  'given',
#  'right',
#  'recall',
#  'members',
#  'parliament',
#  'guilty',
#  'serious',
#  'wrongdoing',
#  'proposals',
#  'brought',
#  'forward',
#  'reformed',
#  'second',
#  'house',
#  'wholly',
#  'mainly',
#  'elected',
#  'basis',
#  'proportional',
#  'representation',
#  'action',
#  'taken',
#  'reform',
#  'funding',
#  'political',
#  'parties',
#  'draft',
#  'bill',
#  'published',
#  'reforming',
#  'parliamentary',
#  'privilege',
#  'legislation',
#  'brought',
#  'forward',
#  'restore',
#  'freedoms',
#  'civil',
#  'liberties',
#  'abolition',
#  'identity',
#  'cards',
#  'repeal',
#  'unnecessary',
#  'laws',
#  'government',
#  'work',
#  'constructively',
#  'devolved',
#  'institutions',
#  'government',
#  'introduce',
#  'legislation',
#  'implement',
#  'recommendations',
#  'final',
#  'report',
#  'commission',
#  'scottish',
#  'devolution',
#  'committed',
#  'referendum',
#  'additional',
#  'powers',
#  'national',
#  'assembly',
#  'wales',
#  'government',
#  'support',
#  'political',
#  'institutions',
#  'stable',
#  'devolved',
#  'government',
#  'northern',
#  'house',
#  'commons',
#  'estimates',
#  'public',
#  'services',
#  'laid',
#  'lords',
#  'members',
#  'house',
#  'commons',
#  'government',
#  'introduce',
#  'legislation',
#  'ensure',
#  'future',
#  'parliament',
#  'british',
#  'people',
#  'say',
#  'proposed',
#  'transfer',
#  'powers',
#  'european',
#  'union',
#  'duke',
#  'edinburgh',
#  'look',
#  'forward',
#  'visit',
#  'canada',
#  'june',
#  'visit',
#  'united',
#  'nations',
#  'new',
#  'york',
#  'july',
#  'also',
#  'look',
#  'forward',
#  'receiving',
#  'holiness',
#  'pope',
#  'benedict',
#  'sixteenth',
#  'september',
#  'government',
#  'seek',
#  'effective',
#  'global',
#  'collaboration',
#  'sustain',
#  'economic',
#  'recovery',
#  'combat',
#  'climate',
#  'change',
#  'including',
#  'climate',
#  'change',
#  'conference',
#  'mexico',
#  'later',
#  'year',
#  'government',
#  'fully',
#  'support',
#  'courageous',
#  'armed',
#  'forces',
#  'undertake',
#  'full',
#  'strategic',
#  'defence',
#  'security',
#  'review',
#  'government',
#  'work',
#  'afghan',
#  'government',
#  'pakistan',
#  'international',
#  'partners',
#  'lasting',
#  'security',
#  'stability',
#  'afghanistan',
#  'government',
#  'looks',
#  'forward',
#  'enhanced',
#  'partnership',
#  'india',
#  'middle',
#  'east',
#  'government',
#  'continue',
#  'work',
#  'solution',
#  'sees',
#  'viable',
#  'palestinian',
#  'state',
#  'existing',
#  'peace',
#  'security',
#  'alongside',
#  'israel',
#  'government',
#  'work',
#  'reduce',
#  'threat',
#  'nuclear',
#  'weapons',
#  'nuclear',
#  'proliferation',
#  'including',
#  'serious',
#  'international',
#  'concerns',
#  'posed',
#  'iran',
#  'nuclear',
#  'programme',
#  'government',
#  'committed',
#  'spend',
#  'nought',
#  'point',
#  'seven',
#  'per',
#  'cent',
#  'gross',
#  'national',
#  'income',
#  'development',
#  'aid',
#  'measures',
#  'laid',
#  'lords',
#  'members',
#  'house',
#  'commons',
#  'pray',
#  'blessing',
#  'almighty',
#  'god',
#  'may',
#  'rest',
#  'upon',
#  'counsels']
